# %%
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

# %%
num_topics = 10
n_top_words = 20

# %%
data, _ = fetch_20newsgroups(shuffle=True, random_state=1,
                             remove=('headers', 'footers', 'quotes'),
                             return_X_y=True)


tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                max_features=n_features,
                                stop_words='english')

tf = tf_vectorizer.fit_transform(data)


lda = LatentDirichletAllocation(n_components=num_topics, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
lda.fit(tf)


tf_feature_names = tf_vectorizer.get_feature_names()

# %%
def get_topics(model, n_top_words, num_topics):
    feat_names = tf_vectorizer.get_feature_names()
    
    word_dict = {}
    for i in range(num_topics):
        words_ids = model.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = words
    
    return pd.DataFrame(word_dict)

# %%
import pandas as pd
get_topics(lda, n_top_words, num_topics)
# Out:
#    Topic # 01  Topic # 02 Topic # 03 Topic # 04   Topic # 05 Topic # 06  \
# 0      people  government      space        key          edu        god
# 1         gun      people    program        car         file     people
# 2    armenian         law     output       chip          com       does
# 3   armenians          mr      entry       used    available      jesus
# 4         war         use       data       keys         mail        say
# 5     turkish   president       nasa       bike          ftp      think
# 6      states         don        use        use        files    believe
# 7      israel       think    science        bit  information        don
# 8        said       right   research    clipper        image       know
# 9    children      public      build     number         send       just
# 10       jews        make    section      phone         list        way
# 11        000       state     center       like          use       like
# 12      state       going     launch       cars      version       true
# 13        new     privacy       time       just       server   question
# 14       guns     private       high     engine        email       life
# 15    israeli    security      earth     ground          pub       time
# 16         vs        know       year        des     software  christian
# 17   military         new      rules  algorithm           cs        did
# 18      years      rights       long       good         code      point
# 19   american        want  satellite     secret       window      bible
#
#    Topic # 07 Topic # 08 Topic # 09 Topic # 10
# 0     windows         ax       just         10
# 1         use        max        don         00
# 2       drive        b8f       like         25
# 3      thanks        g9v      think         15
# 4        does        a86       know         12
# 5     problem         pl       good         20
# 6        know        145       time         11
# 7        card        1d9         ve         14
# 8        like         0t     people         17
# 9       using        34u       said         16
# 10         db         1t       year         13
# 11       scsi         3t        did         30
# 12        dos        giz       didn         24
# 13       disk        bhj        got         50
# 14        bit         wm         ll         18
# 15       need        2di      going         19
# 16         pc        75u        way         27
# 17     memory        2tm       game         40
# 18        mac         cx     really         21
# 19       work        bxn       team        new
